# %% [markdown]
# # Установка инструментов Data Science
# Проверка Python, pip, Jupyter и ключевых библиотек.

# %%
import sys
print(f'Python: {sys.version}')

import numpy as np
print(f'NumPy: {np.__version__}')

import pandas as pd
print(f'Pandas: {pd.__version__}')

import sklearn
print(f'Scikit-learn: {sklearn.__version__}')

# %%
import matplotlib
import seaborn
print(f'Matplotlib: {matplotlib.__version__}')
print(f'Seaborn: {seaborn.__version__}')

# %% [markdown]
# ## Quick Test
# Запустите эту ячейку — если ошибок нет, всё установлено correctamente.

# %%
print('✅ Все библиотеки установлены!')
